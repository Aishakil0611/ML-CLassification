# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset.drop("User ID",axis=1)
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
independent=dataset[["Age","EstimatedSalary","Gender_Male"]]
dependent=dataset[["Purchased"]]

# %%
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
independent.shape
# Out:
# (400, 3)

# %%
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#split training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(independent, dependent, test_size=1/3, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(x_train,y_train)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_11360\4228702713.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(x_train,y_train)
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[10,50,100,500,1000],'criterion':['gini','entropy','log_loss'],'max_features':['sqrt','log2']}
grid=GridSearchCV(RandomForestClassifier(), param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100, 500, 1000]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(x_test)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93        85
#            1       0.87      0.92      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.92      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
print("Theconfusion_matrix value for best parameter {}:".format(grid.best_params_))
# Out:
# Theconfusion_matrix value for best parameter {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 1000}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.031784      0.001642         0.005845        0.000080
# 1        0.119393      0.009581         0.008695        0.002271
# 2        0.188692      0.019559         0.013668        0.001786
# 3        0.819509      0.008794         0.050339        0.002066
# 4        1.613766      0.025147         0.093747        0.013978
# 5        0.023327      0.002023         0.003576        0.000465
# 6        0.090938      0.008005         0.008544        0.004480
# 7        0.165377      0.007498         0.012499        0.006249
# 8        0.756860      0.012637         0.043750        0.006251
# 9        1.569256      0.021043         0.081247        0.011692
# 10       0.021877      0.007655         0.000000        0.000000
# 11       0.084378      0.007654         0.009374        0.007654
# 12       0.165625      0.007653         0.009374        0.007654
# ...

# %%
age_input=float(input("Age:"))
salary_input=float(input("Estimated_Salar:"))
gender_input=float(input("Gender_Male:"))
# Out:
# Age:35
# Estimated_Salar:20000
# Gender_Male:1

# %%
Future_Prediction=grid.predict([[age_input,salary_input,gender_input]])#→change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0]
# C:\Users\acer\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
